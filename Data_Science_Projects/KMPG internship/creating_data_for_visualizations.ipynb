# %%
import pandas as pd

# %%
df = pd.read_csv('kmpg_insternship_cleaned_data.csv',index_col='transaction_id').sort_index()
df.head()
# Out:
#                 product_id  customer_id transaction_date  online_order  \
# transaction_id
# 1                        2         2950       2017-02-25           0.0
# 2                        3         3120       2017-05-21           1.0
# 3                       37          402       2017-10-16           0.0
# 4                       88         3135       2017-08-31           0.0
# 6                       25         2339       2017-03-08           1.0
#
#                          brand product_line product_class product_size  \
# transaction_id
# 1                        Solex     Standard        medium       medium
# 2                Trek Bicycles     Standard        medium        large
# 3                   OHM Cycles     Standard           low       medium
# 4               Norco Bicycles     Standard        medium       medium
# 6               Giant Bicycles         Road        medium       medium
#
#                 list_price  standard_cost  ...         DOB  \
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'customer_id', 'transaction_date', 'online_order',
#        'brand', 'product_line', 'product_class', 'product_size', 'list_price',
#        'standard_cost', 'product_first_sold_date', 'gender',
#        'past_3_years_bike_related_purchases', 'job_title',
#        'job_industry_category', 'wealth_segment', 'owns_car', 'tenure',
#        'address', 'postcode', 'state', 'property_valuation', 'age'],
#       dtype='object')

# %%
df['age']=pd.DatetimeIndex(df.transaction_date).year-pd.DatetimeIndex(df.DOB).year
df.age
# Out:
# transaction_id
# 1        62
# 2        38
# 3        40
# 4        55
# 6        59
#          ..
# 19995    39
# 19996    23
# 19997    43
# 19998    43
# 20000    21
# Name: age, Length: 14062, dtype: int64

# %%
for x in df.age[df.age>120].index:
    df.drop(x, inplace=True)

# %%
df.drop('DOB',axis=1, inplace=True)

# %%
df.to_csv('kmpg_virtual_interm.csv')
